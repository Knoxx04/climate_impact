# %% [markdown]
# ## Data cleaning

# %%
# !pip install pandas

# %%
#import pandas
import pandas as pd

# %%
#confirm if pandas works well
print (pd.__version__)
# Out:
# 2.2.2

# %%
#read csv file
df = pd.read_csv("crop_production.csv")

#checks the top 20 rows
df.head(20)

#delete the last column
df.pop("Flag Codes")

df.head(20)
# Out:
#     index LOCATION  INDICATOR SUBJECT   MEASURE FREQUENCY  TIME      Value
# 0       0      AUS  CROPYIELD    RICE  TONNE_HA         A  1990   8.314607
# 1       1      AUS  CROPYIELD    RICE  TONNE_HA         A  1991   8.394737
# 2       2      AUS  CROPYIELD    RICE  TONNE_HA         A  1992   8.094340
# 3       3      AUS  CROPYIELD    RICE  TONNE_HA         A  1993   8.336000
# 4       4      AUS  CROPYIELD    RICE  TONNE_HA         A  1994   8.537815
# 5       5      AUS  CROPYIELD    RICE  TONNE_HA         A  1995   7.051095
# 6       6      AUS  CROPYIELD    RICE  TONNE_HA         A  1996   8.256579
# 7       7      AUS  CROPYIELD    RICE  TONNE_HA         A  1997   9.006803
# 8       8      AUS  CROPYIELD    RICE  TONNE_HA         A  1998   9.202703
# 9       9      AUS  CROPYIELD    RICE  TONNE_HA         A  1999   8.274809
# 10     10      AUS  CROPYIELD    RICE  TONNE_HA         A  2000   9.282486
# ...

# %%
# define rannge of data to be shown
start_year = 2006
end_year = 2016

#convert str datatype to integer
df["TIME"] = pd.to_numeric(df["TIME"], errors="coerce")


#filter dataframe
filtered_df = df[(df["TIME"] >= start_year) & (df["TIME"] <= end_year)]

print(filtered_df)
# Out:
#        index LOCATION  INDICATOR  SUBJECT   MEASURE FREQUENCY  TIME  \
# 16        16      AUS  CROPYIELD     RICE  TONNE_HA         A  2006
# 17        17      AUS  CROPYIELD     RICE  TONNE_HA         A  2007
# 18        18      AUS  CROPYIELD     RICE  TONNE_HA         A  2008
# 19        19      AUS  CROPYIELD     RICE  TONNE_HA         A  2009
# 20        20      AUS  CROPYIELD     RICE  TONNE_HA         A  2010
# ...      ...      ...        ...      ...       ...       ...   ...
# 20552  20552     OECD  CROPYIELD  SOYBEAN   THND_HA         A  2012
# 20553  20553     OECD  CROPYIELD  SOYBEAN   THND_HA         A  2013
# 20554  20554     OECD  CROPYIELD  SOYBEAN   THND_HA         A  2014
# 20555  20555     OECD  CROPYIELD  SOYBEAN   THND_HA         A  2015
# 20556  20556     OECD  CROPYIELD  SOYBEAN   THND_HA         A  2016
#
#               Value
# 16         8.150000
# 17         8.500965
# 18         8.460940
# 19        10.389573
# 20         9.544133
# ...             ...
# ...

# %%
#check if dataframe contains null values
filtered_df.isna()
# Out:
#        index  LOCATION  INDICATOR  SUBJECT  MEASURE  FREQUENCY   TIME  Value
# 16     False     False      False    False    False      False  False  False
# 17     False     False      False    False    False      False  False  False
# 18     False     False      False    False    False      False  False  False
# 19     False     False      False    False    False      False  False  False
# 20     False     False      False    False    False      False  False  False
# ...      ...       ...        ...      ...      ...        ...    ...    ...
# 20552  False     False      False    False    False      False  False  False
# 20553  False     False      False    False    False      False  False  False
# 20554  False     False      False    False    False      False  False  False
# 20555  False     False      False    False    False      False  False  False
# 20556  False     False      False    False    False      False  False  False
#
# [6325 rows x 8 columns]

# %%
#loop over columns in the dataframe
for rows in filtered_df.itertuples():
    for columns in filtered_df.columns:
        if column.values == "true":
            list = filtered_df.tolst()

print(list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       2 for rows in filtered_df.itertuples():
#       3     for columns in filtered_df.columns:
# ----> 4         if column.values == "true":
#       5             list = filtered_df.tolst()
#       7 print(list)
#
# NameError: name 'column' is not defined
